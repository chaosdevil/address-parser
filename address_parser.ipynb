# %%
addresses = [
    "71 ซอยเลี่ยงเมืองนนทบุรี 3 แยก 2 ตำบลสวนใหญ่ อำเภอเมือง จังหวัดนนทบุรี 11000",
    "ไทยรัฐออนไลน์ บริษัท เทรนด์ วีจี3 จำกัด อาคาร 17 ชั้น 7, 9 เลขที่ 1 ถนนวิภาวดีรังสิต แขวงจอมพล เขตจตุจักร กรุงเทพฯ 10900 อีเมล: cs@thairath.co.th โทร: 02-127-1222 แฟกช์: 02-272-1783",
    "Bangkok Post Public Company Limited Bangkok Post Building 136 Sunthorn Kosa Road, Klong Toey, Bangkok 10110 Thailand Tel: +662-616-4000 Fax: +662-240-3666",
    "88/99 หมู่บ้านศิริชัย ทวีวัฒนา เขตทวีวัฒนา กรุงเทพมหานคร 11170",
    "71 ซอยเลี่ยงเมืองนนทบุรี 3 แยก 2 ตำบลสวนใหญ่ อำเภอเมือง จังหวัดนนทบุรี 11000",
    "ไทยรัฐออนไลน์ บริษัท เทรนด์ วีจี3 จำกัด อาคาร 17 ชั้น 7, 9 เลขที่ 1 ถนนวิภาวดีรังสิต แขวงจอมพล เขตจตุจักร กรุงเทพฯ 10900 อีเมล: cs@thairath.co.th โทร: 02-127-1222 แฟกช์: 02-272-1783",
    "Bangkok Post Public Company Limited Bangkok Post Building 136 Sunthorn Kosa Road, Klong Toey, Bangkok 10110 Thailand Tel: +662-616-4000 Fax: +662-240-3666",
    "88/99 หมู่บ้านศิริชัย ทวีวัฒนา เขตทวีวัฒนา กรุงเทพมหานคร 11170",
    "71 ซอยเลี่ยงเมืองนนทบุรี 3 แยก 2 ตำบลสวนใหญ่ อำเภอเมือง จังหวัดนนทบุรี 11000",
    "ไทยรัฐออนไลน์ บริษัท เทรนด์ วีจี3 จำกัด อาคาร 17 ชั้น 7, 9 เลขที่ 1 ถนนวิภาวดีรังสิต แขวงจอมพล เขตจตุจักร กรุงเทพฯ 10900 อีเมล: cs@thairath.co.th โทร: 02-127-1222 แฟกช์: 02-272-1783",
    "Bangkok Post Public Company Limited Bangkok Post Building 136 Sunthorn Kosa Road, Klong Toey, Bangkok 10110 Thailand Tel: +662-616-4000 Fax: +662-240-3666",
    "88/99 หมู่บ้านศิริชัย ทวีวัฒนา เขตทวีวัฒนา กรุงเทพมหานคร 11170",
    "71 ซอยเลี่ยงเมืองนนทบุรี 3 แยก 2 ตำบลสวนใหญ่ อำเภอเมือง จังหวัดนนทบุรี 11000",
    "ไทยรัฐออนไลน์ บริษัท เทรนด์ วีจี3 จำกัด อาคาร 17 ชั้น 7, 9 เลขที่ 1 ถนนวิภาวดีรังสิต แขวงจอมพล เขตจตุจักร กรุงเทพฯ 10900 อีเมล: cs@thairath.co.th โทร: 02-127-1222 แฟกช์: 02-272-1783",
    "Bangkok Post Public Company Limited Bangkok Post Building 136 Sunthorn Kosa Road, Klong Toey, Bangkok 10110 Thailand Tel: +662-616-4000 Fax: +662-240-3666",
    "88/99 หมู่บ้านศิริชัย ทวีวัฒนา เขตทวีวัฒนา กรุงเทพมหานคร 11170","71 ซอยเลี่ยงเมืองนนทบุรี 3 แยก 2 ตำบลสวนใหญ่ อำเภอเมือง จังหวัดนนทบุรี 11000",
    "ไทยรัฐออนไลน์ บริษัท เทรนด์ วีจี3 จำกัด อาคาร 17 ชั้น 7, 9 เลขที่ 1 ถนนวิภาวดีรังสิต แขวงจอมพล เขตจตุจักร กรุงเทพฯ 10900 อีเมล: cs@thairath.co.th โทร: 02-127-1222 แฟกช์: 02-272-1783",
    "Bangkok Post Public Company Limited Bangkok Post Building 136 Sunthorn Kosa Road, Klong Toey, Bangkok 10110 Thailand Tel: +662-616-4000 Fax: +662-240-3666",
    "88/99 หมู่บ้านศิริชัย ทวีวัฒนา เขตทวีวัฒนา กรุงเทพมหานคร 11170",
    "71 ซอยเลี่ยงเมืองนนทบุรี 3 แยก 2 ตำบลสวนใหญ่ อำเภอเมือง จังหวัดนนทบุรี 11000",
    "ไทยรัฐออนไลน์ บริษัท เทรนด์ วีจี3 จำกัด อาคาร 17 ชั้น 7, 9 เลขที่ 1 ถนนวิภาวดีรังสิต แขวงจอมพล เขตจตุจักร กรุงเทพฯ 10900 อีเมล: cs@thairath.co.th โทร: 02-127-1222 แฟกช์: 02-272-1783",
    "Bangkok Post Public Company Limited Bangkok Post Building 136 Sunthorn Kosa Road, Klong Toey, Bangkok 10110 Thailand Tel: +662-616-4000 Fax: +662-240-3666",
    "88/99 หมู่บ้านศิริชัย ทวีวัฒนา เขตทวีวัฒนา กรุงเทพมหานคร 11170",
    "71 ซอยเลี่ยงเมืองนนทบุรี 3 แยก 2 ตำบลสวนใหญ่ อำเภอเมือง จังหวัดนนทบุรี 11000",
    "ไทยรัฐออนไลน์ บริษัท เทรนด์ วีจี3 จำกัด อาคาร 17 ชั้น 7, 9 เลขที่ 1 ถนนวิภาวดีรังสิต แขวงจอมพล เขตจตุจักร กรุงเทพฯ 10900 อีเมล: cs@thairath.co.th โทร: 02-127-1222 แฟกช์: 02-272-1783",
    "Bangkok Post Public Company Limited Bangkok Post Building 136 Sunthorn Kosa Road, Klong Toey, Bangkok 10110 Thailand Tel: +662-616-4000 Fax: +662-240-3666",
    "88/99 หมู่บ้านศิริชัย ทวีวัฒนา เขตทวีวัฒนา กรุงเทพมหานคร 11170"
] * 10

# %%
import thaiaddress
import concurrent.futures
import requests
import threading
import time
import logging

from pprint import pprint

# %%
result = []


def address_parse(address: str):
    global result
    # session = get_session()
    # with session.get(address) as response:
    #     print(f"Read {len(response.content)} from {url}")
    parsed_address = thaiaddress.parse(address)
    # print(parsed_address)
    result.append(parsed_address)

# %%
# def thread_function(name):
#     print("Thread %s: starting" % name)
#     time.sleep(2)
#     print("Thread %s: finishing" % name)

# format = "%(asctime)s: %(message)s"
# logging.basicConfig(format=format, level=logging.INFO,
#                     datefmt="%H:%M:%S")
start = time.time()
threads = list()
for address in addresses:
    # print("Main    : create and start thread %d." % index)
    x = threading.Thread(target=address_parse, args=[address])
    threads.append(x)
    x.start()

for index, thread in enumerate(threads):
    # print("Main    : before joining thread %d." % index)
    thread.join()
    # print("Main    : thread %d done" % index)

print(f"Time elapsed: {time.time() - start} secs")
# Out:
# /Users/liubei/address-parser/lib/python3.11/site-packages/keras/src/layers/core/embedding.py:86: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# /Users/liubei/address-parser/lib/python3.11/site-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step
# WARNING:tensorflow:5 out of the last 8 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x4306b2d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 1s 2s/stepWARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x430594720> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 503ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 333ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 376ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 750ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 675ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 4s/stepe
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 4s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 4s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 5s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 6s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 5s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 4s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 917ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 5s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 6s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 6s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 8s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 15s 5s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 17s 10s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 10s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 11s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 12s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 23s 7s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 23s 14s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 23s 7s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 24s 4s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 24s 7s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 25s 15s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 25s 7s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 25s 4s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 25s 15s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 26s 15s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 27s 16s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 39s 12s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 27s 14s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 27s 16s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 7s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 29s 4s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 29s 4s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 7s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 7s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 29s 4s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 7s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 31s 8s/stepe
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 31s 4s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/stepe
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 32s 8s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 31s 4s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 31s 15s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 29s 15s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 30s 8s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 30s 15s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 32s 4s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 30s 16s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 30s 8s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 31s 8s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/stepe
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 31s 4s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 32s 16s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 31s 8s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 31s 8s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 33s 8s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 15s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 4s/stepp
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 35s 18s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 35s 9s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 35s 19s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 35s 4s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 35s 9s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 5s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 37s 10s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 36s 4s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 35s 10s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 36s 21s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 36s 10s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 36s 10s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 37s 21s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 36s 21s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 38s 22s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 39s 11s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 40s 23s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/stepe
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 40s 22s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 42s 24s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 41s 6s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 42s 22s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 43s 5s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 43s 6s/stepp
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 43s 23s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 44s 11s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 44s 5s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 12s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 45s 6s/stepe
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 46s 24s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 44s 12s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 46s 5s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 43s 5s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 42s 6s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 43s 5s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 45s 6s/stepe
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 45s 6s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 45s 5s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 45s 23s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 11s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 45s 6s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 45s 23s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 45s 5s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 45s 6s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 45s 23s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 59s 6s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 45s 6s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 45s 6s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 42s 21s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 60s 8s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 44s 11s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 43s 5s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 44s 5s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 45s 21s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 44s 11s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 11s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 44s 11s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 11s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 46s 5s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 44s 6s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 45s 5s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 46s 6s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 44s 11s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 47s 25s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 47s 25s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 48s 5s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 49s 7s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 47s 13s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 50s 7s/stepe
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 49s 6s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 50s 14s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 50s 7s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 52s 8s/stepe
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 50s 29s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 53s 16s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 56s 17s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 58s 9s/stepe
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 58s 38s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 62s 19s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 58s 9s/stepe
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 59s 7s/stepe
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 60s 7s/stepp
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 61s 38s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 61s 9s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 63s 10s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 62s 9s/stepe
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 64s 8s/stepe
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 63s 9s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 64s 8s/stepe
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 64s 19s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 65s 8s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 65s 8s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 64s 9s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 65s 38s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 65s 10s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 67s 8s/stepe
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 69s 20s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 68s 10s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 68s 8s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 69s 8s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 71s 8s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 70s 10s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 70s 8s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 70s 10s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 69s 10s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 68s 37s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 69s 8s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 70s 8s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 70s 18s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 68s 37s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 70s 9s/stepe
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 69s 17s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 69s 19s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 68s 7s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 69s 9s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 69s 9s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 68s 8s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 69s 8s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 67s 16s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 70s 7s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 66s 31s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 66s 15s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 68s 8s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 65s 31s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 65s 30s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 66s 15s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 66s 8s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 64s 28s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 67s 15s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 65s 30s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 66s 7s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 64s 13s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 64s 14s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 64s 7s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 65s 27s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 67s 6s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 64s 7s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 62s 25s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 63s 12s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 61s 24s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 63s 5s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 63s 6s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 64s 25s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 61s 23s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 61s 6s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 59s 22s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 60s 9s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 58s 9s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 59s 11s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 58s 18s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 59s 5s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 57s 18s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 57s 10s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 57s 4s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 77s 7s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 65s 3s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 67s 7s/step
# Time elapsed: 279.4642779827118 secs

# %%
import logging
import threading
import time

def thread_function(address, index):
    # print("Thread %s: starting" % name)
    # time.sleep(2)
    print("Thread %s: starting" % index)
    thaiaddress.parse(text=address)
    print("Thread %s: finishing" % index)

    # return parsed_address

def thread_function_two(index):
    # print("Thread %s: starting" % name)
    # time.sleep(2)
    # print("Thread %s: starting" % index)
    # parsed_address = thaiaddress.parse(text=address)
    # print("Thread %s: finishing" % index)

    print("Thread %s: starting" % index)
    time.sleep(2)
    print("Thread %s: finishing" % index)

    # return parsed_address

if __name__ == "__main__":
    format = "%(asctime)s: %(message)s"
    logging.basicConfig(format=format, level=logging.INFO,
                        datefmt="%H:%M:%S")

    threads = list()
    addresses = [
        "88/99 หมู่บ้านศิริชัย ทวีวัฒนา เขตทวีวัฒนา กรุงเทพมหานคร 11170",
        "71 ซอยเลี่ยงเมืองนนทบุรี 3 แยก 2 ตำบลสวนใหญ่ อำเภอเมือง จังหวัดนนทบุรี 11000",
        "ไทยรัฐออนไลน์ บริษัท เทรนด์ วีจี3 จำกัด อาคาร 17 ชั้น 7, 9 เลขที่ 1 ถนนวิภาวดีรังสิต แขวงจอมพล เขตจตุจักร กรุงเทพฯ 10900 อีเมล: cs@thairath.co.th โทร: 02-127-1222 แฟกช์: 02-272-1783"
    ] * 1000
    # for index in range(10000):
    #     print("Main    : create and start thread %d." % index)
    #     x = threading.Thread(target=thread_function_two, args=(index,))
    #     threads.append(x)
    #     x.start()

    for index, address in enumerate(addresses):
        print("Main    : create and start thread %d." % index)
        x = threading.Thread(target=thread_function, args=(address, index, ))
        threads.append(x)
        x.start()

    for index, thread in enumerate(threads):
        print("Main    : before joining thread %d." % index)
        thread.join()
        print("Main    : thread %d done" % index)
# Out:
# Main    : create and start thread 0.
# Thread 0: starting
# Main    : create and start thread 1.
# Thread 1: starting
# Main    : create and start thread 2.
# Thread 2: starting
# Main    : create and start thread 3.
# Thread 3: starting
# Main    : create and start thread 4.
# Thread 4: starting
# Main    : create and start thread 5.
# Thread 5: starting
# Main    : create and start thread 6.
# Thread 6: starting
# Main    : create and start thread 7.
# Thread 7: starting
# Main    : create and start thread 8.
# Thread 8: starting
# Main    : create and start thread 9.
# Thread 9: starting
# Main    : create and start thread 10.
# Thread 10: starting
# Main    : create and start thread 11.
# Thread 11: starting
# Main    : create and start thread 12.
# Thread 12: starting
# Main    : create and start thread 13.
# Thread 13: starting
# Main    : create and start thread 14.
# Thread 14: starting
# Main    : create and start thread 15.
# Thread 15: starting
# Main    : create and start thread 16.
# Thread 16: starting
# Main    : create and start thread 17.
# Thread 17: starting
# Main    : create and start thread 18.
# Thread 18: starting
# Main    : create and start thread 19.
# Thread 19: starting
# Main    : create and start thread 20.
# Thread 20: starting
# Main    : create and start thread 21.
# Thread 21: starting
# Main    : create and start thread 22.
# Thread 22: starting
# Main    : create and start thread 23.
# Thread 23: starting
# Main    : create and start thread 24.
# Thread 24: starting
# Main    : create and start thread 25.
# Thread 25: starting
# Main    : create and start thread 26.
# Thread 26: starting
# Main    : create and start thread 27.
# Thread 27: starting
# Main    : create and start thread 28.
# Thread 28: starting
# Main    : create and start thread 29.
# Thread 29: starting
# Main    : create and start thread 30.
# Thread 30: starting
# Main    : create and start thread 31.
# Thread 31: starting
# Main    : create and start thread 32.
# Thread 32: starting
# Main    : create and start thread 33.
# Thread 33: starting
# Main    : create and start thread 34.
# Thread 34: starting
# Main    : create and start thread 35.
# Thread 35: starting
# Main    : create and start thread 36.
# Thread 36: starting
# Main    : create and start thread 37.
# Thread 37: starting
# Main    : create and start thread 38.
# Thread 38: starting
# Main    : create and start thread 39.
# Thread 39: starting
# Main    : create and start thread 40.
# Thread 40: starting
# Main    : create and start thread 41.
# Thread 41: starting
# Main    : create and start thread 42.
# Thread 42: starting
# Main    : create and start thread 43.
# Thread 43: starting
# Main    : create and start thread 44.
# Thread 44: starting
# Main    : create and start thread 45.
# Thread 45: starting
# Main    : create and start thread 46.
# Thread 46: starting
# Main    : create and start thread 47.
# Thread 47: starting
# /Users/liubei/address-parser/lib/python3.11/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# /Users/liubei/address-parser/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Main    : create and start thread 48.
# Thread 48: starting
# Main    : create and start thread 49.
# Thread 49: starting
# Main    : create and start thread 50.
# Thread 50: starting
# Main    : create and start thread 51.
# Thread 51: starting
# Main    : create and start thread 52.
# Thread 52: starting
# Main    : create and start thread 53.
# Thread 53: starting
# Main    : create and start thread 54.
# Thread 54: starting
# Main    : create and start thread 55.
# Thread 55: starting
# Main    : create and start thread 56.
# Thread 56: starting
# Main    : create and start thread 57.
# Thread 57: starting
# Main    : create and start thread 58.
# Thread 58: starting
# Main    : create and start thread 59.
# Thread 59: starting
# Main    : create and start thread 60.
# Thread 60: starting
# Main    : create and start thread 61.
# Thread 61: starting
# Main    : create and start thread 62.
# Thread 62: starting
# Main    : create and start thread 63.
# Thread 63: starting
# Main    : create and start thread 64.
# Thread 64: starting
# Main    : create and start thread 65.
# Thread 65: starting
# Main    : create and start thread 66.
# Thread 66: starting
# Main    : create and start thread 67.
# Thread 67: starting
# Main    : create and start thread 68.
# Thread 68: starting
# Main    : create and start thread 69.
# Thread 69: starting
# Main    : create and start thread 70.
# Thread 70: startingMain    : create and start thread 71.
# Thread 71: starting
#
# Main    : create and start thread 72.
# Thread 72: starting
# Main    : create and start thread 73.
# Thread 73: starting
# Main    : create and start thread 74.
# Thread 74: starting
# Main    : create and start thread 75.
# Thread 75: starting
# Main    : create and start thread 76.
# Thread 76: starting
# Main    : create and start thread 77.
# Thread 77: starting
# Main    : create and start thread 78.
# Thread 78: starting
# Main    : create and start thread 79.
# Thread 79: starting
# Main    : create and start thread 80.
# Thread 80: starting
# Main    : create and start thread 81.
# Thread 81: starting
# Main    : create and start thread 82.
# Thread 82: starting
# Main    : create and start thread 83.
# Thread 83: starting
# Main    : create and start thread 84.
# Thread 84: starting
# Main    : create and start thread 85.
# Thread 85: starting
# Main    : create and start thread 86.
# Thread 86: starting
# Main    : create and start thread 87.
# Thread 87: starting
# Main    : create and start thread 88.
# Thread 88: starting
# Main    : create and start thread 89.
# Thread 89: starting
# Main    : create and start thread 90.
# Thread 90: starting
# Main    : create and start thread 91.
# Thread 91: starting
# Main    : create and start thread 92.
# Thread 92: starting
# Main    : create and start thread 93.
# Thread 93: starting
# Main    : create and start thread 94.
# Thread 94: starting
# Main    : create and start thread 95.
# Thread 95: starting
# Main    : create and start thread 96.
# Thread 96: starting
# Main    : create and start thread 97.
# Thread 97: starting
# Main    : create and start thread 98.
# Thread 98: starting
# Main    : create and start thread 99.
# Thread 99: starting
# Main    : create and start thread 100.
# Thread 100: starting
# Main    : create and start thread 101.
# Thread 101: starting
# Main    : create and start thread 102.
# Thread 102: starting
# Main    : create and start thread 103.
# Thread 103: starting
# Main    : create and start thread 104.
# Thread 104: starting
# Main    : create and start thread 105.
# Thread 105: starting
# Main    : create and start thread 106.
# Thread 106: starting
# Main    : create and start thread 107.
# Thread 107: starting
# Main    : create and start thread 108.
# Thread 108: starting
# Main    : create and start thread 109.
# Thread 109: starting
# Main    : create and start thread 110.
# Thread 110: starting
# Main    : create and start thread 111.
# Thread 111: starting
# Main    : create and start thread 112.
# Thread 112: starting
# Main    : create and start thread 113.
# Thread 113: starting
# Main    : create and start thread 114.
# Thread 114: starting
# Main    : create and start thread 115.
# Thread 115: starting
# Main    : create and start thread 116.
# Thread 116: starting
# Main    : create and start thread 117.
# Thread 117: starting
# Main    : create and start thread 118.
# Thread 118: starting
# Main    : create and start thread 119.
# Thread 119: starting
# Main    : create and start thread 120.
# Thread 120: starting
# Main    : create and start thread 121.
# Thread 121: starting
# Main    : create and start thread 122.
# Thread 122: starting
# Main    : create and start thread 123.
# Thread 123: starting
# Main    : create and start thread 124.
# Thread 124: starting
# Main    : create and start thread 125.
# Thread 125: starting
# Main    : create and start thread 126.
# Thread 126: startingMain    : create and start thread 127.
# Thread 127: starting
# Main    : create and start thread 128.
# Thread 128: starting
#
# Main    : create and start thread 129.
# Thread 129: starting
# Main    : create and start thread 130.
# Thread 130: starting
# Main    : create and start thread 131.
# Thread 131: starting
# Main    : create and start thread 132.
# Thread 132: starting
# Main    : create and start thread 133.
# Thread 133: starting
# Main    : create and start thread 134.
# Thread 134: startingMain    : create and start thread 135.
#
# Thread 135: starting
# Main    : create and start thread 136.
# Thread 136: starting
# Main    : create and start thread 137.
# Thread 137: starting
# Main    : create and start thread 138.
# Thread 138: starting
# Main    : create and start thread 139.
# Thread 139: starting
# Main    : create and start thread 140.
# Thread 140: starting
# Main    : create and start thread 141.
# Thread 141: starting
# Main    : create and start thread 142.
# Thread 142: starting
# Main    : create and start thread 143.
# Thread 143: starting
# Main    : create and start thread 144.
# Thread 144: starting
# Main    : create and start thread 145.
# Thread 145: starting
# Main    : create and start thread 146.
# Thread 146: starting
# Main    : create and start thread 147.
# Thread 147: starting
# Main    : create and start thread 148.
# Thread 148: starting
# Main    : create and start thread 149.
# Thread 149: starting
# Main    : create and start thread 150.
# Thread 150: starting
# Main    : create and start thread 151.
# Thread 151: starting
# Main    : create and start thread 152.
# Thread 152: starting
# Main    : create and start thread 153.
# Thread 153: starting
# Main    : create and start thread 154.
# Thread 154: starting
# Main    : create and start thread 155.
# Thread 155: starting
# Main    : create and start thread 156.
# Thread 156: starting
# Main    : create and start thread 157.
# Thread 157: starting
# Main    : create and start thread 158.
# Thread 158: starting
# Main    : create and start thread 159.
# Thread 159: starting
# Main    : create and start thread 160.
# Thread 160: starting
# Main    : create and start thread 161.
# Thread 161: starting
# Main    : create and start thread 162.
# Thread 162: starting
# Main    : create and start thread 163.
# Thread 163: starting
# Main    : create and start thread 164.
# Thread 164: starting
# Main    : create and start thread 165.
# Thread 165: starting
# Main    : create and start thread 166.
# Thread 166: starting
# Main    : create and start thread 167.
# Thread 167: starting
# Main    : create and start thread 168.
# Thread 168: startingMain    : create and start thread 169.
# Thread 169: starting
#
# Main    : create and start thread 170.
# Thread 170: starting
# Main    : create and start thread 171.
# Thread 171: starting
# Main    : create and start thread 172.
# Thread 172: starting
# Main    : create and start thread 173.
# Thread 173: startingMain    : create and start thread 174.
#
# Thread 174: starting
# Main    : create and start thread 175.
# Thread 175: starting
# Main    : create and start thread 176.
# Thread 176: starting
# Main    : create and start thread 177.
# Thread 177: starting
# Main    : create and start thread 178.
# Thread 178: starting
# Main    : create and start thread 179.
# Thread 179: starting
# Main    : create and start thread 180.
# Thread 180: starting
# Main    : create and start thread 181.
# Thread 181: starting
# Main    : create and start thread 182.
# Thread 182: starting
# Main    : create and start thread 183.
# Thread 183: starting
# Main    : create and start thread 184.
# Thread 184: starting
# Main    : create and start thread 185.
# Thread 185: starting
# Main    : create and start thread 186.
# Thread 186: starting
# Main    : create and start thread 187.
# Thread 187: starting
# Main    : create and start thread 188.
# Thread 188: starting
# Main    : create and start thread 189.
# Thread 189: starting
# Main    : create and start thread 190.
# Thread 190: starting
# Main    : create and start thread 191.
# Thread 191: starting
# Main    : create and start thread 192.
# Thread 192: starting
# Main    : create and start thread 193.
# Thread 193: starting
# Main    : create and start thread 194.
# Thread 194: starting
# Main    : create and start thread 195.
# Thread 195: starting
# Main    : create and start thread 196.
# Thread 196: starting
# Main    : create and start thread 197.
# Thread 197: starting
# Main    : create and start thread 198.
# Thread 198: startingMain    : create and start thread 199.
#
# Thread 199: starting
# Main    : create and start thread 200.
# Thread 200: starting
# Main    : create and start thread 201.
# Thread 201: starting
# Main    : create and start thread 202.
# Thread 202: starting
# Main    : create and start thread 203.
# Thread 203: starting
# Main    : create and start thread 204.
# Thread 204: starting
# Main    : create and start thread 205.
# Thread 205: starting
# Main    : create and start thread 206.
# Thread 206: starting
# Main    : create and start thread 207.
# Thread 207: starting
# Main    : create and start thread 208.
# Thread 208: starting
# Main    : create and start thread 209.
# Thread 209: starting
# Main    : create and start thread 210.
# Thread 210: starting
# Main    : create and start thread 211.
# Thread 211: starting
# Main    : create and start thread 212.
# Thread 212: starting
# Main    : create and start thread 213.
# Thread 213: starting
# Main    : create and start thread 214.
# Thread 214: starting
# Main    : create and start thread 215.
# Thread 215: starting
# Main    : create and start thread 216.
# Thread 216: starting
# Main    : create and start thread 217.
# Thread 217: starting
# Main    : create and start thread 218.
# Thread 218: starting
# Main    : create and start thread 219.
# Thread 219: starting
# Main    : create and start thread 220.
# Thread 220: starting
# Main    : create and start thread 221.
# Thread 221: starting
# Main    : create and start thread 222.
# Thread 222: startingMain    : create and start thread 223.
#
# Thread 223: starting
# Main    : create and start thread 224.
# Thread 224: starting
# Main    : create and start thread 225.
# Thread 225: starting
# Main    : create and start thread 226.
# Thread 226: starting
# Main    : create and start thread 227.
# Thread 227: starting
# Main    : create and start thread 228.
# Thread 228: starting
# Main    : create and start thread 229.
# Thread 229: starting
# Main    : create and start thread 230.
# Thread 230: starting
# Main    : create and start thread 231.
# Thread 231: starting
# Main    : create and start thread 232.
# Thread 232: starting
# Main    : create and start thread 233.
# Thread 233: starting
# Main    : create and start thread 234.
# Thread 234: starting
# Main    : create and start thread 235.
# Thread 235: starting
# Main    : create and start thread 236.
# Thread 236: starting
# Main    : create and start thread 237.
# Thread 237: starting
# Main    : create and start thread 238.
# Thread 238: starting
# Main    : create and start thread 239.
# Thread 239: starting
# Main    : create and start thread 240.
# Thread 240: starting
# Main    : create and start thread 241.
# Thread 241: starting
# Main    : create and start thread 242.
# Thread 242: starting
# Main    : create and start thread 243.
# Thread 243: starting
# Main    : create and start thread 244.
# Thread 244: starting
# Main    : create and start thread 245.
# Thread 245: starting
# Main    : create and start thread 246.
# Thread 246: starting
# Main    : create and start thread 247.
# Thread 247: starting
# Main    : create and start thread 248.
# Thread 248: starting
# Main    : create and start thread 249.
# Thread 249: starting
# Main    : create and start thread 250.
# Thread 250: starting
# Main    : create and start thread 251.
# Thread 251: starting
# Main    : create and start thread 252.
# Thread 252: starting
# Main    : create and start thread 253.
# Thread 253: starting
# Main    : create and start thread 254.
# Thread 254: starting
# Main    : create and start thread 255.
# Thread 255: starting
# Main    : create and start thread 256.
# Thread 256: starting
# Main    : create and start thread 257.
# Thread 257: starting
# Main    : create and start thread 258.
# Thread 258: starting
# Main    : create and start thread 259.
# Thread 259: starting
# Main    : create and start thread 260.
# Thread 260: starting
# Main    : create and start thread 261.
# Thread 261: starting
# Main    : create and start thread 262.
# Thread 262: startingMain    : create and start thread 263.
#
# Thread 263: starting
# Main    : create and start thread 264.
# Thread 264: starting
# Main    : create and start thread 265.
# Thread 265: starting
# Main    : create and start thread 266.
# Thread 266: starting
# Main    : create and start thread 267.
# Thread 267: starting
# Main    : create and start thread 268.
# Thread 268: starting
# Main    : create and start thread 269.
# Thread 269: starting
# Main    : create and start thread 270.
# Thread 270: starting
# Main    : create and start thread 271.
# Thread 271: starting
# Main    : create and start thread 272.
# Thread 272: starting
# Main    : create and start thread 273.
# Thread 273: starting
# Main    : create and start thread 274.
# Thread 274: starting
# Main    : create and start thread 275.
# Thread 275: starting
# Main    : create and start thread 276.
# Thread 276: starting
# Main    : create and start thread 277.
# Thread 277: starting
# Main    : create and start thread 278.
# Thread 278: starting
# Main    : create and start thread 279.
# Thread 279: starting
# Main    : create and start thread 280.
# Thread 280: starting
# Main    : create and start thread 281.
# Thread 281: starting
# Main    : create and start thread 282.
# Thread 282: starting
# Main    : create and start thread 283.
# Thread 283: starting
# Main    : create and start thread 284.
# Thread 284: starting
# Main    : create and start thread 285.
# Thread 285: starting
# Main    : create and start thread 286.
# Thread 286: starting
# Main    : create and start thread 287.
# Thread 287: starting
# Main    : create and start thread 288.
# Thread 288: starting
# Main    : create and start thread 289.
# Thread 289: starting
# Main    : create and start thread 290.
# Thread 290: starting
# Main    : create and start thread 291.
# Thread 291: starting
# Main    : create and start thread 292.
# Thread 292: starting
# Main    : create and start thread 293.
# Thread 293: starting
# Main    : create and start thread 294.
# Thread 294: starting
# Main    : create and start thread 295.
# Thread 295: starting
# Main    : create and start thread 296.
# Thread 296: starting
# Main    : create and start thread 297.
# Thread 297: starting
# Main    : create and start thread 298.
# Thread 298: starting
# Main    : create and start thread 299.
# Thread 299: starting
# Main    : create and start thread 300.
# Thread 300: starting
# Main    : create and start thread 301.
# Thread 301: starting
# Main    : create and start thread 302.
# Thread 302: starting
# Main    : create and start thread 303.
# Thread 303: starting
# Main    : create and start thread 304.
# Thread 304: starting
# Main    : create and start thread 305.
# Thread 305: starting
# Main    : create and start thread 306.
# Thread 306: starting
# Main    : create and start thread 307.
# Thread 307: starting
# Main    : create and start thread 308.
# Thread 308: starting
# Main    : create and start thread 309.
# Thread 309: startingMain    : create and start thread 310.
#
# Thread 310: starting
# Main    : create and start thread 311.
# Thread 311: starting
# Main    : create and start thread 312.
# Thread 312: starting
# Main    : create and start thread 313.
# Thread 313: starting
# Main    : create and start thread 314.
# Thread 314: starting
# Main    : create and start thread 315.
# Thread 315: starting
# Main    : create and start thread 316.
# Thread 316: starting
# Main    : create and start thread 317.
# Thread 317: starting
# Main    : create and start thread 318.
# Thread 318: starting
# Main    : create and start thread 319.
# Thread 319: starting
# Main    : create and start thread 320.
# Thread 320: starting
# Main    : create and start thread 321.
# Thread 321: starting
# Main    : create and start thread 322.
# Thread 322: starting
# Main    : create and start thread 323.
# Thread 323: starting
# Main    : create and start thread 324.
# Thread 324: starting
# Main    : create and start thread 325.
# Thread 325: starting
# Main    : create and start thread 326.
# Thread 326: starting
# Main    : create and start thread 327.
# Thread 327: starting
# Main    : create and start thread 328.
# Thread 328: starting
# Main    : create and start thread 329.
# Thread 329: starting
# Main    : create and start thread 330.
# Thread 330: starting
# Main    : create and start thread 331.
# Thread 331: starting
# Main    : create and start thread 332.
# Thread 332: starting
# Main    : create and start thread 333.
# Thread 333: starting
# Main    : create and start thread 334.
# Thread 334: starting
# Main    : create and start thread 335.
# Thread 335: starting
# Main    : create and start thread 336.
# Thread 336: starting
# Main    : create and start thread 337.
# Thread 337: starting
# Main    : create and start thread 338.
# Thread 338: starting
# Main    : create and start thread 339.
# Thread 339: starting
# Main    : create and start thread 340.
# Thread 340: starting
# Main    : create and start thread 341.
# Thread 341: startingMain    : create and start thread 342.
#
# Thread 342: starting
# Main    : create and start thread 343.
# Thread 343: starting
# Main    : create and start thread 344.
# Thread 344: starting
# Main    : create and start thread 345.
# Thread 345: starting
# Main    : create and start thread 346.
# Thread 346: starting
# Main    : create and start thread 347.
# Thread 347: starting
# Main    : create and start thread 348.
# Thread 348: starting
# Main    : create and start thread 349.
# Thread 349: starting
# Main    : create and start thread 350.
# Thread 350: starting
# Main    : create and start thread 351.
# Thread 351: starting
# Main    : create and start thread 352.
# Thread 352: starting
# Main    : create and start thread 353.
# Thread 353: startingMain    : create and start thread 354.
# Thread 354: starting
# Main    : create and start thread 355.
#
# Thread 355: starting
# Main    : create and start thread 356.
# Thread 356: starting
# Main    : create and start thread 357.
# Thread 357: starting
# Main    : create and start thread 358.
# Thread 358: starting
# Main    : create and start thread 359.
# Thread 359: starting
# Main    : create and start thread 360.
# Thread 360: starting
# Main    : create and start thread 361.
# Thread 361: starting
# Main    : create and start thread 362.
# Thread 362: starting
# Main    : create and start thread 363.
# Thread 363: starting
# Main    : create and start thread 364.
# Thread 364: starting
# Main    : create and start thread 365.
# Thread 365: starting
# Main    : create and start thread 366.
# Thread 366: starting
# Main    : create and start thread 367.
# Thread 367: starting
# Main    : create and start thread 368.
# Thread 368: starting
# Main    : create and start thread 369.
# Thread 369: starting
# Main    : create and start thread 370.
# Thread 370: starting
# Main    : create and start thread 371.
# Thread 371: starting
# Main    : create and start thread 372.
# Thread 372: starting
# Main    : create and start thread 373.
# Thread 373: starting
# Main    : create and start thread 374.
# Thread 374: starting
# Main    : create and start thread 375.
# Thread 375: starting
# Main    : create and start thread 376.
# Thread 376: starting
# Main    : create and start thread 377.
# Thread 377: starting
# Main    : create and start thread 378.
# Thread 378: starting
# Main    : create and start thread 379.
# Thread 379: starting
# Main    : create and start thread 380.
# Thread 380: starting
# Main    : create and start thread 381.
# Thread 381: starting
# Main    : create and start thread 382.
# Thread 382: starting
# Main    : create and start thread 383.
# Thread 383: starting
# Main    : create and start thread 384.
# Thread 384: starting
# Main    : create and start thread 385.
# Thread 385: starting
# Main    : create and start thread 386.
# Thread 386: starting
# Main    : create and start thread 387.
# Thread 387: starting
# Main    : create and start thread 388.
# Thread 388: starting
# Main    : create and start thread 389.
# Thread 389: starting
# Main    : create and start thread 390.
# Thread 390: starting
# Main    : create and start thread 391.
# Thread 391: starting
# Main    : create and start thread 392.
# Thread 392: starting
# Main    : create and start thread 393.
# Thread 393: starting
# Main    : create and start thread 394.
# Thread 394: starting
# Main    : create and start thread 395.
# Thread 395: starting
# Main    : create and start thread 396.
# Thread 396: starting
# Main    : create and start thread 397.
# Thread 397: starting
# Main    : create and start thread 398.
# Thread 398: starting
# Main    : create and start thread 399.
# Thread 399: starting
# Main    : create and start thread 400.
# Thread 400: starting
# Main    : create and start thread 401.
# Thread 401: starting
# Main    : create and start thread 402.
# Thread 402: starting
# Main    : create and start thread 403.
# Thread 403: starting
# Main    : create and start thread 404.
# Thread 404: starting
# Main    : create and start thread 405.
# Thread 405: starting
# Main    : create and start thread 406.
# Thread 406: starting
# Main    : create and start thread 407.
# Thread 407: starting
# Main    : create and start thread 408.
# Thread 408: starting
# Main    : create and start thread 409.
# Thread 409: starting
# Main    : create and start thread 410.
# Thread 410: starting
# Main    : create and start thread 411.
# Thread 411: starting
# Main    : create and start thread 412.
# Thread 412: starting
# Main    : create and start thread 413.
# Thread 413: starting
# Main    : create and start thread 414.
# Thread 414: starting
# Main    : create and start thread 415.
# Thread 415: starting
# Main    : create and start thread 416.
# Thread 416: starting
# Main    : create and start thread 417.
# Thread 417: starting
# Main    : create and start thread 418.
# Thread 418: starting
# Main    : create and start thread 419.
# Thread 419: starting
# Main    : create and start thread 420.
# Thread 420: starting
# Main    : create and start thread 421.
# Thread 421: starting
# Main    : create and start thread 422.
# Thread 422: starting
# Main    : create and start thread 423.
# Thread 423: starting
# Main    : create and start thread 424.
# Thread 424: starting
# Main    : create and start thread 425.
# Thread 425: starting
# Main    : create and start thread 426.
# Thread 426: starting
# Main    : create and start thread 427.
# Thread 427: starting
# Main    : create and start thread 428.
# Thread 428: starting
# Main    : create and start thread 429.
# Thread 429: starting
# Main    : create and start thread 430.
# Thread 430: starting
# Main    : create and start thread 431.
# Thread 431: starting
# Main    : create and start thread 432.
# Thread 432: starting
# Main    : create and start thread 433.
# Thread 433: starting
# Main    : create and start thread 434.
# Thread 434: starting
# Main    : create and start thread 435.
# Thread 435: starting
# Main    : create and start thread 436.
# Thread 436: starting
# Main    : create and start thread 437.
# Thread 437: starting
# Main    : create and start thread 438.
# Thread 438: starting
# Main    : create and start thread 439.
# Thread 439: starting
# Main    : create and start thread 440.
# Thread 440: starting
# Main    : create and start thread 441.
# Thread 441: startingMain    : create and start thread 442.
#
# Thread 442: starting
# Main    : create and start thread 443.
# Thread 443: starting
# Main    : create and start thread 444.
# Thread 444: starting
# Main    : create and start thread 445.
# Thread 445: starting
# Main    : create and start thread 446.
# Thread 446: startingMain    : create and start thread 447.
# Thread 447: starting
#
# Main    : create and start thread 448.
# Thread 448: starting
# Main    : create and start thread 449.
# Thread 449: starting
# Main    : create and start thread 450.
# Thread 450: starting
# Main    : create and start thread 451.
# Thread 451: starting
# Main    : create and start thread 452.
# Thread 452: starting
# Main    : create and start thread 453.
# Thread 453: startingMain    : create and start thread 454.
#
# Thread 454: starting
# Main    : create and start thread 455.
# Thread 455: starting
# Main    : create and start thread 456.
# Thread 456: starting
# Main    : create and start thread 457.
# Thread 457: starting
# Main    : create and start thread 458.
# Thread 458: starting
# Main    : create and start thread 459.
# Thread 459: starting
# Main    : create and start thread 460.
# Thread 460: starting
# Main    : create and start thread 461.
# Thread 461: starting
# Main    : create and start thread 462.
# Thread 462: starting
# Main    : create and start thread 463.
# Thread 463: starting
# Main    : create and start thread 464.
# Thread 464: starting
# Main    : create and start thread 465.
# Thread 465: starting
# Main    : create and start thread 466.
# Thread 466: starting
# Main    : create and start thread 467.
# Thread 467: starting
# Main    : create and start thread 468.
# Thread 468: starting
# Main    : create and start thread 469.
# Thread 469: starting
# Main    : create and start thread 470.
# Thread 470: starting
# Main    : create and start thread 471.
# Thread 471: starting
# Main    : create and start thread 472.
# Thread 472: starting
# Main    : create and start thread 473.
# Thread 473: starting
# Main    : create and start thread 474.
# Thread 474: starting
# Main    : create and start thread 475.
# Thread 475: starting
# Main    : create and start thread 476.
# Thread 476: starting
# Main    : create and start thread 477.
# Thread 477: startingMain    : create and start thread 478.
#
# Thread 478: starting
# Main    : create and start thread 479.
# Thread 479: starting
# Main    : create and start thread 480.
# Thread 480: starting
# Main    : create and start thread 481.
# Thread 481: starting
# Main    : create and start thread 482.
# Thread 482: starting
# Main    : create and start thread 483.
# Thread 483: starting
# Main    : create and start thread 484.
# Thread 484: starting
# Main    : create and start thread 485.
# Thread 485: starting
# Main    : create and start thread 486.
# Thread 486: starting
# Main    : create and start thread 487.
# Thread 487: startingMain    : create and start thread 488.
# Thread 488: starting
#
# Main    : create and start thread 489.
# Thread 489: starting
# Main    : create and start thread 490.
# Thread 490: starting
# Main    : create and start thread 491.
# Thread 491: starting
# Main    : create and start thread 492.
# Thread 492: starting
# Main    : create and start thread 493.
# Thread 493: starting
# Main    : create and start thread 494.
# Thread 494: starting
# Main    : create and start thread 495.
# Thread 495: starting
# Main    : create and start thread 496.
# Thread 496: starting
# Main    : create and start thread 497.
# Thread 497: startingMain    : create and start thread 498.
# Thread 498: starting
#
# Main    : create and start thread 499.
# Thread 499: starting
# Main    : create and start thread 500.
# Thread 500: starting
# Main    : create and start thread 501.
# Thread 501: starting
# Main    : create and start thread 502.
# Thread 502: starting
# Main    : create and start thread 503.
# Thread 503: starting
# Main    : create and start thread 504.
# Thread 504: starting
# Main    : create and start thread 505.
# Thread 505: starting
# Main    : create and start thread 506.
# Thread 506: starting
# Main    : create and start thread 507.
# Thread 507: starting
# Main    : create and start thread 508.
# Thread 508: starting
# Main    : create and start thread 509.
# Thread 509: starting
# Main    : create and start thread 510.
# Thread 510: starting
# Main    : create and start thread 511.
# Thread 511: starting
# Main    : create and start thread 512.
# Thread 512: starting
# Main    : create and start thread 513.
# Thread 513: starting
# Main    : create and start thread 514.
# Thread 514: starting
# Main    : create and start thread 515.
# Thread 515: starting
# Main    : create and start thread 516.
# Thread 516: starting
# Main    : create and start thread 517.
# Thread 517: starting
# Main    : create and start thread 518.
# Thread 518: starting
# Main    : create and start thread 519.
# Thread 519: starting
# Main    : create and start thread 520.
# Thread 520: starting
# Main    : create and start thread 521.
# Thread 521: starting
# Main    : create and start thread 522.
# Thread 522: starting
# Main    : create and start thread 523.
# Thread 523: starting
# Main    : create and start thread 524.
# Thread 524: starting
# Main    : create and start thread 525.
# Thread 525: starting
# Main    : create and start thread 526.
# Thread 526: starting
# Main    : create and start thread 527.
# Thread 527: starting
# Main    : create and start thread 528.
# Thread 528: starting
# Main    : create and start thread 529.
# Thread 529: starting
# Main    : create and start thread 530.
# Thread 530: starting
# Main    : create and start thread 531.
# Thread 531: starting
# Main    : create and start thread 532.
# Thread 532: starting
# Main    : create and start thread 533.
# Thread 533: starting
# Main    : create and start thread 534.
# Thread 534: starting
# Main    : create and start thread 535.
# Thread 535: starting
# Main    : create and start thread 536.
# Thread 536: starting
# Main    : create and start thread 537.
# Thread 537: starting
# Main    : create and start thread 538.
# Thread 538: starting
# Main    : create and start thread 539.
# Thread 539: starting
# Main    : create and start thread 540.
# Thread 540: starting
# Main    : create and start thread 541.
# Thread 541: starting
# Main    : create and start thread 542.
# Thread 542: starting
# Main    : create and start thread 543.
# Thread 543: starting
# Main    : create and start thread 544.
# Thread 544: starting
# Main    : create and start thread 545.
# Thread 545: starting
# Main    : create and start thread 546.
# Thread 546: starting
# Main    : create and start thread 547.
# Thread 547: starting
# Main    : create and start thread 548.
# Thread 548: starting
# Main    : create and start thread 549.
# Thread 549: starting
# Main    : create and start thread 550.
# Thread 550: starting
# Main    : create and start thread 551.
# Thread 551: starting
# Main    : create and start thread 552.
# Thread 552: starting
# Main    : create and start thread 553.
# Thread 553: starting
# Main    : create and start thread 554.
# Thread 554: starting
# Main    : create and start thread 555.
# Thread 555: starting
# Main    : create and start thread 556.
# Thread 556: starting
# Main    : create and start thread 557.
# Thread 557: starting
# Main    : create and start thread 558.
# Thread 558: starting
# Main    : create and start thread 559.
# Thread 559: starting
# Main    : create and start thread 560.
# Thread 560: starting
# Main    : create and start thread 561.
# Thread 561: starting
# Main    : create and start thread 562.
# Thread 562: starting
# Main    : create and start thread 563.
# Thread 563: starting
# Main    : create and start thread 564.
# Thread 564: starting
# Main    : create and start thread 565.
# Thread 565: startingMain    : create and start thread 566.
#
# Thread 566: starting
# Main    : create and start thread 567.
# Thread 567: starting
# Main    : create and start thread 568.
# Thread 568: starting
# Main    : create and start thread 569.
# Thread 569: starting
# Main    : create and start thread 570.
# Thread 570: starting
# Main    : create and start thread 571.
# Thread 571: starting
# Main    : create and start thread 572.
# Thread 572: starting
# Main    : create and start thread 573.
# Thread 573: starting
# Main    : create and start thread 574.
# Thread 574: starting
# Main    : create and start thread 575.
# Thread 575: starting
# Main    : create and start thread 576.
# Thread 576: starting
# Main    : create and start thread 577.
# Thread 577: starting
# Main    : create and start thread 578.
# Thread 578: starting
# Main    : create and start thread 579.
# Thread 579: starting
# Main    : create and start thread 580.
# Thread 580: starting
# Main    : create and start thread 581.
# Thread 581: starting
# Main    : create and start thread 582.
# Thread 582: starting
# Main    : create and start thread 583.
# Thread 583: starting
# Main    : create and start thread 584.
# Thread 584: starting
# Main    : create and start thread 585.
# Thread 585: starting
# Main    : create and start thread 586.
# Thread 586: startingMain    : create and start thread 587.
# Thread 587: starting
#
# Main    : create and start thread 588.
# Thread 588: starting
# Main    : create and start thread 589.
# Thread 589: starting
# Main    : create and start thread 590.
# Thread 590: starting
# Main    : create and start thread 591.
# Thread 591: starting
# Main    : create and start thread 592.
# Thread 592: starting
# Main    : create and start thread 593.
# Thread 593: starting
# Main    : create and start thread 594.
# Thread 594: starting
# Main    : create and start thread 595.
# Thread 595: starting
# Main    : create and start thread 596.
# Thread 596: starting
# Main    : create and start thread 597.
# Thread 597: starting
# Main    : create and start thread 598.
# Thread 598: starting
# Main    : create and start thread 599.
# Thread 599: starting
# Main    : create and start thread 600.
# Thread 600: starting
# Main    : create and start thread 601.
# Thread 601: starting
# Main    : create and start thread 602.
# Thread 602: starting
# Main    : create and start thread 603.
# Thread 603: starting
# Main    : create and start thread 604.
# Thread 604: starting
# Main    : create and start thread 605.
# Thread 605: starting
# Main    : create and start thread 606.
# Thread 606: starting
# Main    : create and start thread 607.
# Thread 607: starting
# Main    : create and start thread 608.
# Thread 608: starting
# Main    : create and start thread 609.
# Thread 609: starting
# Main    : create and start thread 610.
# Thread 610: starting
# Main    : create and start thread 611.
# Thread 611: starting
# Main    : create and start thread 612.
# Thread 612: starting
# Main    : create and start thread 613.
# Thread 613: starting
# Main    : create and start thread 614.
# Thread 614: starting
# Main    : create and start thread 615.
# Thread 615: starting
# Main    : create and start thread 616.
# Thread 616: starting
# Main    : create and start thread 617.
# Thread 617: starting
# Main    : create and start thread 618.
# Thread 618: starting
# Main    : create and start thread 619.
# Thread 619: starting
# Main    : create and start thread 620.
# Thread 620: starting
# Main    : create and start thread 621.
# Thread 621: starting
# Main    : create and start thread 622.
# Thread 622: starting
# Main    : create and start thread 623.
# Thread 623: starting
# Main    : create and start thread 624.
# Thread 624: starting
# Main    : create and start thread 625.
# Thread 625: starting
# Main    : create and start thread 626.
# Thread 626: starting
# Main    : create and start thread 627.
# Thread 627: starting
# Main    : create and start thread 628.
# Thread 628: starting
# Main    : create and start thread 629.
# Thread 629: starting
# Main    : create and start thread 630.
# Thread 630: starting
# Main    : create and start thread 631.
# Thread 631: starting
# Main    : create and start thread 632.
# Thread 632: starting
# Main    : create and start thread 633.
# Thread 633: starting
# Main    : create and start thread 634.
# Thread 634: starting
# Main    : create and start thread 635.
# Thread 635: starting
# Main    : create and start thread 636.
# Thread 636: starting
# Main    : create and start thread 637.
# Thread 637: starting
# Main    : create and start thread 638.
# Thread 638: starting
# Main    : create and start thread 639.
# Thread 639: starting
# Main    : create and start thread 640.
# Thread 640: starting
# Main    : create and start thread 641.
# Thread 641: starting
# Main    : create and start thread 642.
# Thread 642: starting
# Main    : create and start thread 643.
# Thread 643: starting
# Main    : create and start thread 644.
# Thread 644: starting
# Main    : create and start thread 645.
# Thread 645: starting
# Main    : create and start thread 646.
# Thread 646: startingMain    : create and start thread 647.
# Thread 647: starting
#
# Main    : create and start thread 648.
# Thread 648: starting
# Main    : create and start thread 649.
# Thread 649: starting
# Main    : create and start thread 650.
# Thread 650: starting
# Main    : create and start thread 651.
# Thread 651: starting
# Main    : create and start thread 652.
# Thread 652: starting
# Main    : create and start thread 653.
# Thread 653: starting
# Main    : create and start thread 654.
# Thread 654: starting
# Main    : create and start thread 655.
# Thread 655: starting
# Main    : create and start thread 656.
# Thread 656: starting
# Main    : create and start thread 657.
# Thread 657: starting
# Main    : create and start thread 658.
# Thread 658: starting
# Main    : create and start thread 659.
# Thread 659: starting
# Main    : create and start thread 660.
# Thread 660: starting
# Main    : create and start thread 661.
# Thread 661: starting
# Main    : create and start thread 662.
# Thread 662: starting
# Main    : create and start thread 663.
# Thread 663: starting
# Main    : create and start thread 664.
# Thread 664: starting
# Main    : create and start thread 665.
# Thread 665: starting
# Main    : create and start thread 666.
# Thread 666: starting
# Main    : create and start thread 667.
# Thread 667: startingMain    : create and start thread 668.
#
# Thread 668: starting
# Main    : create and start thread 669.
# Thread 669: starting
# Main    : create and start thread 670.
# Thread 670: starting
# Main    : create and start thread 671.
# Thread 671: starting
# Main    : create and start thread 672.
# Thread 672: starting
# Main    : create and start thread 673.
# Thread 673: starting
# Main    : create and start thread 674.
# Thread 674: starting
# Main    : create and start thread 675.
# Thread 675: starting
# Main    : create and start thread 676.
# Thread 676: starting
# Main    : create and start thread 677.
# Thread 677: starting
# Main    : create and start thread 678.
# Thread 678: starting
# Main    : create and start thread 679.
# Thread 679: starting
# Main    : create and start thread 680.
# Thread 680: starting
# Main    : create and start thread 681.
# Thread 681: starting
# Main    : create and start thread 682.
# Thread 682: startingMain    : create and start thread 683.
#
# Thread 683: starting
# Main    : create and start thread 684.
# Thread 684: starting
# Main    : create and start thread 685.
# Thread 685: starting
# Main    : create and start thread 686.
# Thread 686: starting
# Main    : create and start thread 687.
# Thread 687: starting
# Main    : create and start thread 688.
# Thread 688: starting
# Main    : create and start thread 689.
# Thread 689: starting
# Main    : create and start thread 690.
# Thread 690: starting
# Main    : create and start thread 691.
# Thread 691: starting
# Main    : create and start thread 692.
# Thread 692: starting
# Main    : create and start thread 693.
# Thread 693: starting
# Main    : create and start thread 694.
# Thread 694: starting
# Main    : create and start thread 695.
# Thread 695: starting
# Main    : create and start thread 696.
# Thread 696: startingMain    : create and start thread 697.
#
# Thread 697: starting
# Main    : create and start thread 698.
# Thread 698: starting
# Main    : create and start thread 699.
# Thread 699: starting
# Main    : create and start thread 700.
# Thread 700: starting
# Main    : create and start thread 701.
# Thread 701: starting
# Main    : create and start thread 702.
# Thread 702: starting
# Main    : create and start thread 703.
# Thread 703: starting
# Main    : create and start thread 704.
# Thread 704: starting
# Main    : create and start thread 705.
# Thread 705: starting
# Main    : create and start thread 706.
# Thread 706: starting
# Main    : create and start thread 707.
# Thread 707: starting
# Main    : create and start thread 708.
# Thread 708: starting
# Main    : create and start thread 709.
# Thread 709: starting
# Main    : create and start thread 710.
# Thread 710: starting
# Main    : create and start thread 711.
# Thread 711: starting
# Main    : create and start thread 712.
# Thread 712: starting
# Main    : create and start thread 713.
# Thread 713: starting
# Main    : create and start thread 714.
# Thread 714: starting
# Main    : create and start thread 715.
# Thread 715: starting
# Main    : create and start thread 716.
# Thread 716: starting
# Main    : create and start thread 717.
# Thread 717: starting
# Main    : create and start thread 718.
# Thread 718: starting
# Main    : create and start thread 719.
# Thread 719: starting
# Main    : create and start thread 720.
# Thread 720: starting
# Main    : create and start thread 721.
# Thread 721: starting
# Main    : create and start thread 722.
# Thread 722: starting
# Main    : create and start thread 723.
# Thread 723: starting
# Main    : create and start thread 724.
# Thread 724: starting
# Main    : create and start thread 725.
# Thread 725: starting
# Main    : create and start thread 726.
# Thread 726: starting
# Main    : create and start thread 727.
# Thread 727: starting
# Main    : create and start thread 728.
# Thread 728: starting
# Main    : create and start thread 729.
# Thread 729: starting
# Main    : create and start thread 730.
# Thread 730: starting
# Main    : create and start thread 731.
# Thread 731: starting
# Main    : create and start thread 732.
# Thread 732: starting
# Main    : create and start thread 733.
# Thread 733: starting
# Main    : create and start thread 734.
# Thread 734: starting
# Main    : create and start thread 735.
# Thread 735: starting
# Main    : create and start thread 736.
# Thread 736: starting
# Main    : create and start thread 737.
# Thread 737: starting
# Main    : create and start thread 738.
# Thread 738: starting
# Main    : create and start thread 739.
# Thread 739: starting
# Main    : create and start thread 740.
# Thread 740: starting
# Main    : create and start thread 741.
# Thread 741: starting
# Main    : create and start thread 742.
# Thread 742: starting
# Main    : create and start thread 743.
# Thread 743: starting
# Main    : create and start thread 744.
# Thread 744: starting
# Main    : create and start thread 745.
# Thread 745: starting
# Main    : create and start thread 746.
# Thread 746: starting
# Main    : create and start thread 747.
# Thread 747: starting
# Main    : create and start thread 748.
# Thread 748: starting
# Main    : create and start thread 749.
# Thread 749: starting
# Main    : create and start thread 750.
# Thread 750: starting
# Main    : create and start thread 751.
# Thread 751: starting
# Main    : create and start thread 752.
# Thread 752: starting
# Main    : create and start thread 753.
# Thread 753: starting
# Main    : create and start thread 754.
# Thread 754: starting
# Main    : create and start thread 755.
# Thread 755: starting
# Main    : create and start thread 756.
# Thread 756: starting
# Main    : create and start thread 757.
# Thread 757: starting
# Main    : create and start thread 758.
# Thread 758: starting
# Main    : create and start thread 759.
# Thread 759: starting
# Main    : create and start thread 760.
# Thread 760: starting
# Main    : create and start thread 761.
# Thread 761: starting
# Main    : create and start thread 762.
# Thread 762: starting
# Main    : create and start thread 763.
# Thread 763: starting
# Main    : create and start thread 764.
# Thread 764: starting
# Main    : create and start thread 765.
# Thread 765: starting
# Main    : create and start thread 766.
# Thread 766: starting
# Main    : create and start thread 767.
# Thread 767: starting
# Main    : create and start thread 768.
# Thread 768: starting
# Main    : create and start thread 769.
# Thread 769: starting
# Main    : create and start thread 770.
# Thread 770: starting
# Main    : create and start thread 771.
# Thread 771: starting
# Main    : create and start thread 772.
# Thread 772: starting
# Main    : create and start thread 773.
# Thread 773: starting
# Main    : create and start thread 774.
# Thread 774: starting
# Main    : create and start thread 775.
# Thread 775: starting
# Main    : create and start thread 776.
# Thread 776: starting
# Main    : create and start thread 777.
# Thread 777: starting
# Main    : create and start thread 778.
# Thread 778: starting
# Main    : create and start thread 779.
# Thread 779: starting
# Main    : create and start thread 780.
# Thread 780: starting
# Main    : create and start thread 781.
# Thread 781: starting
# Main    : create and start thread 782.
# Thread 782: starting
# Main    : create and start thread 783.
# Thread 783: starting
# Main    : create and start thread 784.
# Thread 784: starting
# Main    : create and start thread 785.
# Thread 785: starting
# Main    : create and start thread 786.
# Thread 786: starting
# Main    : create and start thread 787.
# Thread 787: starting
# Main    : create and start thread 788.
# Thread 788: starting
# Main    : create and start thread 789.
# Thread 789: starting
# Main    : create and start thread 790.
# Thread 790: starting
# Main    : create and start thread 791.
# Thread 791: starting
# Main    : create and start thread 792.
# Thread 792: starting
# Main    : create and start thread 793.
# Thread 793: starting
# Main    : create and start thread 794.
# ...
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/stepThread 779: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 5s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 5s/step
# Thread 367: finishing
# Thread 622: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 10s/step
# Thread 2361: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 9s/step
# Thread 1107: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 5s/step
# 4/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/stepThread 637: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 5s/step
# Thread 839: finishing
# Thread 409: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 9s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step  Thread 2067: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 5s/step
# Thread 556: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 9s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step
# Thread 359: finishing
# Thread 2103: finishing
# Thread 581: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step
# Thread 2717: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step
# Thread 2753: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step
# Thread 1304: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 9s 10s/stepThread 623: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 10s/step
# Thread 1389: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 9s/step
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/stepThread 1824: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 36s 28s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 36s 14s/step
# Thread 834: finishingThread 391: finishing
#
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 44s 35s/step
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/stepThread 2469: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 44s 18s/step
# Thread 1555: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 51s 8s/step
# Thread 2528: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 53s 43s/step
# Thread 201: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 52s 43s/step
# Thread 696: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 52s 9s/step
# Thread 2084: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 52s 21s/step
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 42s 43s/stepThread 2659: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 56s 22s/step
# 3/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step Thread 735: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 59s 5s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 58s 11s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 59s 12s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 59s 12s/step
# Thread 218: finishingThread 1309: finishing
#
# Thread 2782: finishing
# Thread 1735: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 59s 12s/step
# Thread 2224: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 59s 12s/step
# Thread 607: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 63s 20s/step
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/stepThread 1056: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step
# Thread 1520: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 29s 11s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 29s 11s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step
# Thread 972: finishing
# Thread 1653: finishing
# Thread 1625: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step Thread 2102: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 31s 12s/step
# Thread 2109: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 31s 6s/step
# Thread 2755: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 33s 13s/step
# Thread 441: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step
# Thread 602: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step
# Thread 1436: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 7s/step
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 27s 14s/stepThread 2347: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step
# Thread 2366: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 26s 14s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step  Thread 2535: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 26s 7s/step
# Thread 2560: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 3s/stepe
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/stepThread 1220: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 27s 14s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step Thread 1632: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 27s 14s/step
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 13s 14s/stepThread 585: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 1:10 14s/stepThread 2732: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 7s/stepe
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 7s/step
# Thread 2149: finishing
# Thread 760: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 7s/step
# Thread 2875: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 8s/step
# Thread 605: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step  Thread 1360: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step
# Thread 2852: finishing
# Thread 2891: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 30s 8s/step
# Thread 793: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 30s 17s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step  Thread 99: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/stepe
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/stepThread 1022: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 8s/step
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 30s 15s/stepThread 2407: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step
# Thread 1889: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 30s 16s/step
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 1:21 16s/steppThread 650: finishing
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/stepThread 1947: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 31s 18s/step
# Thread 2493: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step
# Thread 1562: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 32s 17s/step
# Thread 1200: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 31s 16s/step
# Thread 2679: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 31s 16s/step
# Thread 2130: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 31s 15s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step Thread 576: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 31s 16s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step  Thread 2733: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step
# Thread 1685: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step
# Thread 2714: finishing
# Thread 1715: finishing
# Thread 158: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 30s 7s/step
# Thread 472: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 128s 7s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 29s 13s/step
# Thread 2858: finishingThread 2828: finishing
#
# Thread 940: finishing
# Thread 1773: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 6s/step
# Thread 994: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step
# Thread 635: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step
# Thread 800: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 6s/step
# 3/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step Thread 2329: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 28s 11s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 29s 11s/step
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/stepThread 2991: finishing
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/stepThread 2343: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 6s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 29s 12s/step
# Thread 1867: finishing
# Thread 2385: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 25s 5s/step
# Thread 1534: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 8s/step
# Thread 2607: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step
# Thread 2068: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step
# Thread 2693: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 4s/step
# Thread 1285: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 4s/step
# Thread 1699: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step
# Thread 463: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 4s/step
# Thread 2902: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 9s/step
# Thread 2271: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 9s/step
# 2/6 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/stepThread 2268: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 5s/step
# Thread 1420: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 17s 8s/step
# Thread 663: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 4s/step
# Thread 1894: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 17s 8s/step
# Thread 2499: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 5s/step
# Thread 2536: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 10s/step
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/stepThread 426: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 5s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step
# 2/6 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/stepThread 2632: finishing
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/stepThread 1640: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step
# 4/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/stepThread 2678: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 5s/step
# Thread 2131: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 10s/step
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 52s 11s/stepThread 2787: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 11s/step
# Thread 2262: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 5s/step
# Thread 2320: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 10s/step
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/stepThread 1872: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 10s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step
# Thread 1118: finishing
# Thread 2442: finishing
# Thread 1514: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 10s/step
# Thread 894: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 11s/step
# Thread 1566: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step
# Thread 689: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 22s 11s/step
# Thread 2019: finishing
# Thread 1193: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 10s/step
# Thread 1608: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 22s 6s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step
# Thread 1243: finishing
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 52s 10s/stepThread 569: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 21s 5s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 10s/step
# Thread 1321: finishing
# Thread 2832: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 22s 11s/step
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step Thread 225: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 10s/step
# Thread 1365: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 11s/step
# Thread 1860: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 23s 12s/step
# 4/6 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/stepThread 654: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 23s 3s/step
# 4/6 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/stepThread 1922: finishi
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 39s 29s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30s/step Thread 2496: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 40s 30s/step
# Thread 1986: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 44s 34s/step
# Thread 2001: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 48s 7s/step
# 3/6 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/stepThread 188: finishi
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 47s 18s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 48s 37s/step
# Thread 2071: finishing
# Thread 1203: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 49s 38s/step
# Thread 252: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 51s 38s/step
# Thread 753: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 51s 8s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 52s 25s/step
# Thread 2864: finishing
# Thread 600: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 52s 12s/step
# Thread 2887: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 53s 4s/step
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/stepThread 2918: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 53s 17s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 53s 17s/step
# Thread 378: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step  Thread 630: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 54s 9s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 53s 4s/step
# Thread 2986: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step
# Thread 2360: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 54s 18s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 53s 4s/step
# Thread 1028: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step   Thread 2349: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 54s 9s/step
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 16s 17s/stepThread 833: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step Thread 1459: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 55s 18s/step
# Thread 1467: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 56s 9s/step
# Thread 2386: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 55s 9s/stepp
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/stepThread 1486: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 55s 18s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step Thread 507: finishin
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 55s 18s/step
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 1:31 18s/stepThread 2439: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 56s 18s/step
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/stepThread 1536: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 57s 4s/step
# Thread 308: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 56s 3s/step
# Thread 254: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 56s 3s/step
# Thread 533: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 57s 18s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 56s 8s/step
# Thread 162: finishing
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/stepThread 1222: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 1:23 17s/stepThread 2636: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 32s 8s/step
# Thread 944: finishing
# Thread 2146: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 31s 7s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 31s 14s/step
# Thread 2752: finishing
# Thread 2187: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 32s 7s/step
# Thread 604: finishing
# Thread 1775: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 33s 7s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 32s 7s/step
# Thread 791: finishing
# Thread 2938: finishing
# Thread 625: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step
# Thread 806: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 31s 8s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 32s 8s/step
# Thread 1117: finishing
# Thread 2401: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 4s/step
# Thread 665: finishing
# Thread 260: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 32s 17s/step
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/stepThread 1134: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 4s/step
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 34s 17s/stepThread 2438: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 30s 9s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/stepThread 2605: finishing
# Thread 1601: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 30s 7s/step
# Thread 1852: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 30s 14s/step
# Thread 632: finishing
# Thread 2352: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 31s 7s/step
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/stepThread 1441: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 31s 7s/step
# Thread 1090: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 31s 7s/step
# Thread 505: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 33s 8s/step
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 16s 16s/stepThread 1529: finishing
# Thread 2425: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 34s 17s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 34s 9s/step
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 33s 17s/stepThread 1128: finishing
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/stepThread 1951: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 4s/step
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/stepThread 2489: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 33s 17s/step
# Thread 2058: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 33s 17s/step
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/stepThread 1596: finishing
# Thread 2600: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 32s 8s/step
# Thread 2656: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 8s/step
# Thread 2743: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/stepp
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/stepThread 2690: finishing
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 1:22 16s/stepThread 719: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 29s 15s/step
# Thread 474: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 30s 16s/step
# Thread 84: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 120s 22s/step
# Thread 2198: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 28s 12s/step
# Thread 1431: finishing
# Thread 1829: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 6s/step
# Thread 382: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 5s/step
# Thread 2975: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 5s/step
# Thread 826: finishing
# Thread 1879: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/stepThread 383: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 28s 11s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 5s/step
# Thread 1470: finishing
# Thread 1096: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 5s/step
# Thread 307: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step
# Thread 2555: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step
# Thread 1580: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/stepThread 2870: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 4s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step
# Thread 2356: finishing
# Thread 827: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 4s/step
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/stepThread 511: finishing
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 4s/step
# Thread 2440: finishing
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 9s/step
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 17s 9s/stepThread 2481: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step
# Thread 2456: finishing
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step
# Thread 1991: finishing
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
